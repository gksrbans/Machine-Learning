# %% [markdown]
# <a href="https://colab.research.google.com/github/gksrbans/Machine-Learning/blob/master/TensorFlow%EB%A1%9C_%EA%B0%84%EB%8B%A8%ED%95%9C_linear_regression%EC%9D%84_%EA%B5%AC%ED%98%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# tf.__version__

# x_train = [1,2,3]
# y_train = [1,2,3]

x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float32)

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# 우리의 가설
hypothesis = x_train * W + b
cost = tf.reduce_mean(tf.square(hypothesis - y_train))
# reduce_mean = 평균내줌

#GradientDesceent
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

# for step in range(2001):
#   sess.run(train)
#   if step % 20 == 0:
#     print(step, sess.run(cost), sess.run(W), sess.run(b))


for step in range(2001):
  cost_val, W_val, b_val, _ = \
    sess.run([cost, W, b, train], 
             feed_dict={x: [1, 2, 3], y: [1, 2, 3]})
  if step % 20 == 0: print(step, cost_val, W_val, b_val)
# Out:
# 0 1.5419291 [1.9377275] [-1.052614]
# 20 0.20929466 [1.552502] [-1.1532198]
# 40 0.17928536 [1.494052] [-1.1133126]
# 60 0.16273189 [1.4677402] [-1.0623516]
# 80 0.14779481 [1.4454635] [-1.0125545]
# 100 0.13422962 [1.4245005] [-0.9649806]
# 120 0.12190953 [1.4045477] [-0.91963124]
# 140 0.110720135 [1.3855351] [-0.87641203]
# 160 0.10055777 [1.3674164] [-0.83522385]
# 180 0.09132818 [1.3501493] [-0.7959714]
# 200 0.08294576 [1.3336935] [-0.7585637]
# 220 0.075332634 [1.3180112] [-0.72291404]
# 240 0.068418324 [1.3030658] [-0.68893975]
# 260 0.062138613 [1.2888229] [-0.65656203]
# 280 0.05643529 [1.2752492] [-0.62570614]
# 300 0.05125542 [1.2623135] [-0.59630024]
# 320 0.04655099 [1.2499858] [-0.5682762]
# 340 0.04227838 [1.2382374] [-0.5415695]
# 360 0.038397904 [1.2270411] [-0.51611775]
# 380 0.034873594 [1.2163709] [-0.49186203]
# 400 0.031672742 [1.2062024] [-0.4687464]
# 420 0.0287657 [1.1965116] [-0.44671714]
# 440 0.026125493 [1.1872762] [-0.42572308]
# ...

# %%
tf.print(msg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3408ceb30c52> in <module>()
# ----> 1 tf.print(msg)
#
# NameError: name 'tf' is not defined
